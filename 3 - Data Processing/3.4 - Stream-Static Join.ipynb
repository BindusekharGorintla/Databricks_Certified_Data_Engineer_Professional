# %% [markdown]
# <div  style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://raw.githubusercontent.com/derar-alhussein/Databricks-Certified-Data-Engineer-Professional/main/Includes/images/books_sales.png" width="60%">
# </div>

# %%
# %run ../Includes/Copy-Datasets
# Out:
# Data catalog: workspace
# Schema: bookstore_eng_pro

# %%
from pyspark.sql import functions as F

def process_books_sales():
    
    orders_df = (spark.readStream.table("orders_silver")
                        .withColumn("book", F.explode("books"))
                )

    books_df = spark.read.table("current_books")

    query = (orders_df
                  .join(books_df, orders_df.book.book_id == books_df.book_id, "inner")
                  .writeStream
                     .outputMode("append")
                     .option("checkpointLocation", f"{bookstore.checkpoint_path}/books_sales")
                     .trigger(availableNow=True)
                     .table("books_sales")
    )

    query.awaitTermination()
    
process_books_sales()

# %%
# %sql
SELECT * FROM books_sales
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>order_timestamp</th><th>customer_id</th><th>quantity</th><th>total</th><th>books</th><th>book</th><th>book_id</th><th>title</th><th>author</th><th>price</th></tr></thead><tbody><tr><td>000000004188</td><td>2022-01-13T01:06:00.000Z</td><td>C00217</td><td>2</td><td>48</td><td>List(List(B09, 2, 48))</td><td>List(B09, 2, 48)</td><td>B09</td><td>Advanced Data Structures</td><td>Peter Brass</td><td>24.0</td></tr><tr><td>000000004202</td><td>2022-01-14T06:09:00.000Z</td><td>C00226</td><td>2</td><td>77</td><td>List(List(B07, 1, 33), List(B10, 1, 44))</td><td>List(B07, 1, 33)</td><td>B07</td><td>The Hundred-Page Machine Learning</td><td>Andriy Burkov</td><td>33.0</td></tr><tr><td>000000004202</td><td>2022-01-14T06:09:00.000Z</td><td>C00226</td><td>2</td><td>77</td><td>List(List(B07, 1, 33), List(B10, 1, 44))</td><td>List(B10, 1, 44)</td><td>B10</td><td>Beginning Database Design Solutions</td><td>Rod Stephens</td><td>44.0</td></tr><tr><td>000000003777</td><td>2021-12-11T19:04:00.000Z</td><td>C00105</td><td>2</td><td>46</td><td>List(List(B09, 1, 24), List(B06, 1, 22))</td><td>List(B09, 1, 24)</td><td>B09</td><td>Advanced Data Structures</td><td>Peter Brass</td><td>24.0</td></tr><tr><td>000000003777</td><td>2021-12-11T19:04:00.000Z</td><td>C00105</td><td>2</td><td>46</td><td>List(List(B09, 1, 24), List(B06, 1, 22))</td><td>List(B06, 1, 22)</td><td>B06</td><td>Deep Learning with Python</td><td>François Chollet</td><td>22.0</td></tr><tr><td>000000004074</td><td>2022-01-03T21:05:00.000Z</td><td>C00202</td><td>2</td><td>85</td><td>List(List(B08, 1, 41), List(B10, 1, 44))</td><td>List(B08, 1, 41)</td><td>B08</td><td>Quantum Computing for Everyone</td><td>Chris Bernhardt</td><td>41.0</td></tr><tr><td>000000004074</td><td>2022-01-03T21:05:00.000Z</td><td>C00202</td><td>2</td><td>85</td><td>List(List(B08, 1, 41), List(B10, 1, 44))</td><td>List(B10, 1, 44)</td><td>B10</td><td>Beginning Database Design Solutions</td><td>Rod Stephens</td><td>44.0</td></tr><tr><td>000000003656</td><td>2021-11-30T22:07:00.000Z</td><td>C00065</td><td>2</td><td>66</td><td>List(List(B07, 2, 66))</td><td>List(B07, 2, 66)</td><td>B07</td><td>The Hundred-Page Machine Learning</td><td>Andriy Burkov</td><td>33.0</td></tr><tr><td>000000003558</td><td>2021-11-23T07:06:00.000Z</td><td>C00006</td><td>2</td><td>46</td><td>List(List(B09, 1, 24), List(B06, 1, 22))</td><td>List(B09, 1, 24)</td><td>B09</td><td>Advanced Data Structures</td><td>Peter Brass</td><td>24.0</td></tr><tr><td>000000003558</td><td>2021-11-23T07:06:00.000Z</td><td>C00006</td><td>2</td><td>46</td><td>List(List(B09, 1, 24), List(B06, 1, 22))</td><td>List(B06, 1, 22)</td><td>B06</td><td>Deep Learning with Python</td><td>François Chollet</td><td>22.0</td></tr><tr><td>000000003903</td><td>2021-12-21T14:08:00.000Z</td><td>C00111</td><td>2</td><td>54</td><td>List(List(B09, 1, 24), List(B12, 1, 30))</td><td>List(B09, 1, 24)</td><td>B09</td><td>Advanced Data Structures</td><td>Peter Brass</td><td>24.0</td></tr><tr><td>000000003903</td><td>2021-12-21T14:08:00.000Z</td><td>C00111</td><td>2</td><td>54</td><td>List(List(B09, 1, 24), List(B12, 1, 30))</td><td>List(B12, 1, 30)</td><td>B12</td><td>Big Data in Practice</td><td>Bernard Marr</td><td>30.0</td></tr><tr><td>000000004043</td><td>2022-01-02T01:06:00.000Z</td><td>C00184</td><td>2</td><td>66</td><td>List(List(B07, 2, 66))</td><td>List(B07, 2, 66)</td><td>B07</td><td>The Hundred-Page Machine Learning</td><td>Andriy Burkov</td><td>33.0</td></tr><tr><td>000000003824</td><td>2021-12-15T21:09:00.000Z</td><td>C00112</td><td>2</td><td>50</td><td>List(List(B02, 1, 28), List(B06, 1, 22))</td><td>List(B02, 1, 28)</td><td>B02</td><td>Learning JavaScript Design Patterns</td><td>Addy Osmani</td><td>28.0</td></tr><tr><td>000000003824</td><td>2021-12-15T21:09:00.000Z</td><td>C00112</td><td>2</td><td>50</td><td>List(List(B02, 1, 28), List(B06, 1, 22))</ ...

# %%
# %sql
SELECT count(*) FROM books_sales
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(*)</th></tr></thead><tbody><tr><td>4076</td></tr></tbody></table></div>

# %%
bookstore.load_new_data()
bookstore.process_bronze()
bookstore.process_books_silver()
bookstore.process_current_books()

process_books_sales()
# Out:
# Loading kafka-streaming-07.json file to the bookstore dataset

# %%
# %sql
SELECT count(*) FROM books_sales
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(*)</th></tr></thead><tbody><tr><td>4076</td></tr></tbody></table></div>

# %%
bookstore.process_orders_silver()

process_books_sales()

# %%
# %sql
SELECT count(*) FROM books_sales
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(*)</th></tr></thead><tbody><tr><td>4582</td></tr></tbody></table></div>
